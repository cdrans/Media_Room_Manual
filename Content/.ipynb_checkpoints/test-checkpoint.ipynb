# %% [markdown]
# # Title

# %%
#| label: eq:test-eqn

import sympy as sym
f = sym.Function('f')
y = sym.Function('y')
n = sym.symbols(r'\alpha')
f = y(n)-2*y(n-1/sym.pi)-5*y(n-2)

f
# Out:
# y(\alpha) - 5*y(\alpha - 2) - 2*y(\alpha - 1/pi)

# %%
```{math} #eq:test-eqn
:label: eq:test-eqn-new
```
# Out:
#   Cell In[3], line 1
#     ```{math} #eq:test-eqn
#     ^
# SyntaxError: invalid syntax
