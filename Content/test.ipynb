# %% [markdown]
# # Title

# %%
#| label: eq:test-eqn

import sympy as sym
f = sym.Function('f')
y = sym.Function('y')
n = sym.symbols(r'\alpha')
f = y(n)-2*y(n-1/sym.pi)-5*y(n-2)

f
var1 = sym.latex(f)

# %% [markdown]
# {{ f }}
# ```{embed} eq:test-eqn
#
# caption
# ```
#
# ```{math} {{ var1 }}
#
# ```
#
# $$F=ma$$
#
# {numref}`eq:test-eqn`

# %%
#| label: eq:test-eqn2

import sympy as sym
from IPython.display import Math
f = sym.Function('f')
y = sym.Function('y')
n = sym.symbols(r'\alpha')
f = y(n)-2*y(n-1/sym.pi)-5*y(n-2)

f
# sym.latex(f"${sym.latex(f)}$")
print("```{math}\n:label: eq:from-sympy\n" + sym.latex(f) + "\n```")
# Out:
# ```{math}
# :label: eq:from-sympy
# y{\left(\alpha \right)} - 5 y{\left(\alpha - 2 \right)} - 2 y{\left(\alpha - \frac{1}{\pi} \right)}
# ```

# %% [markdown]
# ````{math}
# ```{embed} #eq:test-eqn2
# :remove-input: true
# ```
# ````

# %%
#| label: eq:sympy-out
#| name: 2

import sympy as sym
from IPython.display import Math

prefix = 1
counter = 0

y = sym.Function('y')
n = sym.symbols(r'\alpha')
f = y(n) - 2*y(n-1/sym.pi) - 5*y(n-2)

eq = (r'\begin{equation}\label{eq:from-sympy} ' 
      + sym.latex(f) 
      + r'\qquad \qquad '
      + str(prefix + counter/10)
      + r'\end{equation}')

Math(eq)
# Out:
# $\displaystyle \begin{equation}\label{eq:from-sympy} y{\left(\alpha \right)} - 5 y{\left(\alpha - 2 \right)} - 2 y{\left(\alpha - \frac{1}{\pi} \right)}\qquad \qquad 1.0\end{equation}$

# %% [markdown]
# see {numref}`equation 1.0 <eq:sympy-out>`.
